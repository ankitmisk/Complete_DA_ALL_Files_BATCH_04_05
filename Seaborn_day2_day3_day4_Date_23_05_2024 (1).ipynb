# %%
# sns.barplot
# sns.boxplot
# sns.lineplot
# sns.pairplot
# sns.countplot
# sns.distplot
# sns.displot
# sns.histplot
# sns.heatmap
# sns.catplot
# sns.FacetGrid
# sns.lmplot
# sns.scatterplot
# sns.jointplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset('tips')

# %%
df

# %%
ax = sns.barplot(data=df,y = 'day',x='total_bill',errorbar=None,hue = 'sex',palette=sns.color_palette('rainbow',2),
#                 dodge=False
                orient='horizontal',saturation=1)

# for i in ax.containers:
#     plt.bar_label(i,rotation=90)

plt.xticks(range(0,35,10))
plt.legend(loc=2)
plt.show()

# %%
df = sns.load_dataset('penguins')

# %%
df

# %%
ax = sns.barplot(data=df,y = 'body_mass_g',x='island',
                 errorbar=None,
                 hue = 'sex',
                 palette=sns.color_palette('rainbow',2))

for i in ax.containers:
    plt.bar_label(i,rotation=90)

plt.legend(loc=2)
plt.yticks(range(0,9000,1000))
plt.show()

# %%
# sns.countplot

# %%
ax = sns.countplot(data=df,x='sex',hue='sex',palette=sns.color_palette('cool',2),legend='brief')

for i in ax.containers:
    plt.bar_label(i,rotation=90,padding=10)
    
plt.yticks(range(0,200,20))
plt.show()

# %%
df['sex'].value_counts().plot(kind='bar',color=['r','b'])
plt.legend(['Male','Female'])

# %%
df['sex'].value_counts().plot.bar(color=['r','g'],legend=False)
plt.legend(['Male','Female'],loc='best')
plt.show()

# %%
# sns.histplot

# %%
sns.histplot(data=df,x='total_bill',hue='sex',stat='probability',multiple='dodge')

# %% [markdown]
# # Day 3 Seaborn

# %%
# sns.pairplot
# sns.displot
# sns.jointplot
# sns.scatterplot

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# sns.pairplot
# {'scatter', 'kde', 'hist', 'reg'}
sns.pairplot(data=df,hue = 'time',x_vars='tip',y_vars='total_bill',kind='reg',)
plt.show()

# %%
# sns.pairplot
# {'scatter', 'kde', 'hist', 'reg'}
sns.pairplot(data=df,hue = 'time',kind='reg',corner=False)
plt.show()

# %%
# sns.pairplot
# {'scatter', 'kde', 'hist', 'reg'}
sns.pairplot(data=df,hue = 'time',kind='reg',corner=True)
plt.show()

# %%
# sns.scatterplot

# %%
sns.scatterplot(data=df)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df,x='total_bill',y = 'tip',hue='smoker')
plt.show()

# %%
df['smoker'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='smoker'>

# %%
df.plot(kind='scatter',x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df_peng = sns.load_dataset('penguins')
df_peng
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.scatterplot(data = df_peng,x = 'bill_length_mm',y='body_mass_g',hue='sex')
plt.show()

# %%
sns.scatterplot(data = df_peng,x = 'bill_length_mm',y='body_mass_g',
                hue='species',style='species',palette = sns.color_palette('ocean',3),size = 'flipper_length_mm')
plt.yticks(range(3000,12000,2000))
plt.legend(loc=2)
plt.show()

# %%
# sns.jointplot

# %%
# plt.figure(figsize=(2,2))
# { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }
sns.jointplot(data=df,x='tip',y='total_bill',ratio=4,height=4,hue='sex',xlim=(0.5,10.5))
plt.show()

# %%
# sns.displot

# %%
# sns.jointplot(data=df)

# %%
sns.histplot(data=df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.displot(data=df)

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['total_bill'],color='r')
plt.show()

# %%
# sns.heatmap

# %%
# corr,pivot,nullValue
corr_df = df.corr(numeric_only=True)

# %%
sns.heatmap(corr_df,annot=True,fmt='.1g')
plt.show()

# %% [markdown]
# # Day 4

# %%
# sns.heatmap
# sns.catplot
# sns.FacetGrid
# sns.lmplot

# %%
# sns.heatmap
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
corr_df  = df.corr(numeric_only=True)
corr_df
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.figure(figsize=(3,3))
sns.heatmap(corr_df,annot=True,fmt='.1f',cmap=sns.color_palette('rainbow'),
            annot_kws={'color':'k','fontsize':8},
           linewidths=10,linecolor='k')
plt.show()

# %%
described_data = df.describe()
described_data
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.heatmap(described_data)
plt.show()

# %%
# sns.lmplot

# %%
sns.lmplot(df,x = 'total_bill',y='tip',hue='sex',col='day')
plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
# sns.lmplot
sns.lmplot(df,x = 'total_bill',y='tip',hue='sex',col='day',row='time',markers='x')
plt.show()

# %%
# sns.FacetGrid

# %%
h = sns.FacetGrid(data=df,row='smoker',col='day')
h.map_dataframe(sns.countplot,x='sex')
plt.show()

# %%
# sns.catplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset('penguins')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.catplot(data = df,kind='swarm',x = 'species',y = 'bill_length_mm' ,hue = 'sex',col = 'island') 
#"strip", "swarm", "box", "violin","boxen", "point", "bar", or "count".
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(data=df,x = 'who',y='fare',hue='survived',kind='box',col ='class',row = 'embark_town' )
plt.savefig(r"C:\Users\Lenovo\Desktop\catplot.png",dpi=1000)
plt.show()
print('done')
# Out:
# done

# %% [markdown]
# https://seaborn.pydata.org/api.html

# %% [markdown]
# <center><h1>Hello</h1></center>

# %% [markdown]
# <button type="button">Click Me!</button>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 15px 32px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 16px;
#   margin: 4px 2px;
#   cursor: pointer;
# }
#
# .button1 {background-color: #04AA6D;} /* Green */
# .button2 {background-color: #008CBA;} /* Blue */
# </style>
# </head>
# <body>
#
# <button class="button button1">Green</button>
# <button class="button button2">Blue</button>
#
# </body>
# </html>

# %% [markdown]
# <img src="https://s3.ap-south-1.amazonaws.com/myinterviewtrainer-domestic/public_assets/assets/000/000/939/original/uses_of_numpy.jpg" alt="Flowers in Chania">

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
.loc[:3].style.highlight_quantile(q_left=0.85, axis=None, color='yellow')

# %%
df = df.describe().style.background_gradient(cmap=sns.color_palette('rainbow',as_cmap=True))

# %%
df.to_html('jaadoo.html')
print('done')
# Out:
# done
