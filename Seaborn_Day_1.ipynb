# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.load_dataset('tipss')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.load_dataset('tipss')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\seaborn\utils.py:573, in load_dataset(name, cache, data_home, **kws)
#     571 if not os.path.exists(cache_path):
#     572     if name not in get_dataset_names():
# --> 573         raise ValueError(f"'{name}' is not one of the example datasets.")
#     574     urlretrieve(url, cache_path)
#     575 full_path = cache_path
#
# ValueError: 'tipss' is not one of the example datasets.

# %%
sns.__version__
# Out:
# '0.13.2'

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.lineplot.html

# %%
# sns.barplot
# sns.boxplot
# sns.lineplot
# sns.pairplot
# sns.countplot
# sns.distplot
# sns.displot
# sns.histplot
# sns.heatmap
# sns.catplot
# sns.FacetGrid
# sns.lmplot
# sns.scatterplot

# %%
#  sns.load_dataset
# sns.get_dataset_names

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
feb_df = df[df['month'] == 'Feb']
feb_df
# Out:
#      year month  passengers
# 1    1949   Feb         118
# 13   1950   Feb         126
# 25   1951   Feb         150
# 37   1952   Feb         180
# 49   1953   Feb         196
# 61   1954   Feb         188
# 73   1955   Feb         233
# 85   1956   Feb         277
# 97   1957   Feb         301
# 109  1958   Feb         318
# 121  1959   Feb         342
# 133  1960   Feb         391

# %%
plt.figure(figsize=(7,3))
sns.lineplot(data = feb_df,x ='year',y = 'passengers') #,hue = 'month',
# style='month',
# size='passengers'.,
# palette = sns.color_palette('magma',1)

plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
pivot_df = df.pivot_table(values='passengers',index='year',columns='month')
pivot_df
# Out:
# month    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# year
# 1949   112.0  118.0  132.0  129.0  121.0  135.0  148.0  148.0  136.0  119.0
# 1950   115.0  126.0  141.0  135.0  125.0  149.0  170.0  170.0  158.0  133.0
# 1951   145.0  150.0  178.0  163.0  172.0  178.0  199.0  199.0  184.0  162.0
# 1952   171.0  180.0  193.0  181.0  183.0  218.0  230.0  242.0  209.0  191.0
# 1953   196.0  196.0  236.0  235.0  229.0  243.0  264.0  272.0  237.0  211.0
# 1954   204.0  188.0  235.0  227.0  234.0  264.0  302.0  293.0  259.0  229.0
# 1955   242.0  233.0  267.0  269.0  270.0  315.0  364.0  347.0  312.0  274.0
# 1956   284.0  277.0  317.0  313.0  318.0  374.0  413.0  405.0  355.0  306.0
# 1957   315.0  301.0  356.0  348.0  355.0  422.0  465.0  467.0  404.0  347.0
# 1958   340.0  318.0  362.0  348.0  363.0  435.0  491.0  505.0  404.0  359.0
# 1959   360.0  342.0  406.0  396.0  420.0  472.0  548.0  559.0  463.0  407.0
# ...

# %%
sns.lineplot(data=pivot_df,markers=True)
# Out:
# <Axes: xlabel='year'>

# %%
plt.figure(dpi=1000)
plt.title('Year vs Passengers Count')
sns.lineplot(data=df,x='year',y='passengers',hue='month',markers=True,style='month') #style='month'

plt.annotate("Weak!!", xy=(1955, 220), xytext=(1958, 100),arrowprops=dict(arrowstyle="->"))
plt.annotate("TechVidya!!",xy=(1954,500),xytext=(1954, 500))
plt.savefig('Metro.png')
plt.show()
