# %%
(0,255)
(0,255)


# RGB
# BGR


# R :- (0,255)
# G :- (0,255)
# B :- (0,255)

# %%
import matplotlib.pyplot as plt

# %%
virat_array = plt.imread(r"C:\Users\Lenovo\Desktop\virat_brother.jpg")

# %%
arr = virat_array.copy()

# %%
arr

# %%
arr.ndim

# %%
arr.size

# %%
arr.shape

# %%
arr[:,:,0]

# %%
plt.imshow(arr[:,:,0])

# %%
plt.imshow(arr[:,:,1])

# %%
plt.imshow(arr[:,:,2])

# %%
plt.imshow(arr)

# %%
plt.imshow(arr[:,500:1300,:])

# %%
plt.imshow(arr[0:800,500:1300,:])

# %%
plt.imshow(arr)

# %%
arr[:,:,0] = 0

# %%
plt.imshow(arr)

# %%
arr[:,:,1] = 255

# %%
plt.imshow(arr)

# %%
arr[:,:,2] = 0

# %%
plt.imshow(arr)

# %%
arr[:,:,1] = 0
arr[:,:,2] = 0

# %%
plt.imshow(arr)

# %%
plt.imshow(arr-100)

# %%
plt.imshow(arr*255)

# %%
import matplotlib.pyplot as plt
kohli = plt.imread(r"C:\Users\Lenovo\Desktop\kohli_bhai.webp")

# %%
arr1 = kohli.copy()

# %%
plt.imshow(arr1*100)

# %%
plt.imshow(arr1*250)

# %%
import numpy as np
255+255

# %%
for i in range(1,255):
        plt.imshow(arr1+100+i)  
        plt.show()
        display(clear=True)
# Out:
# KeyboardInterrupt

# %%
plt.imshow(arr1+255)

# %%
plt.imshow(arr)

# %%
arr[320:430,860:1000,:] = 0

# %%
arr[330:450,1040:1180,:] = 255

# %%
plt.imshow(arr)
